# %% [markdown]
# Столбчатая диаграмма населения России с 2012 по 2022 года

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(10, 7))
Year = ['2012','2013','2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
Popular = [142020000, 143070000, 146020000,145000000,144009000,147000000,146009000,145780720,144600098, 145620098]

plt.bar(Year, Popular)
# Out:
# <BarContainer object of 10 artists>
